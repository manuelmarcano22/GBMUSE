# %%
import camelot

import numpy as np

# %%
tables = camelot.read_pdf('M30Xray.pdf',pages='16,17,18', flavor='stream',row_tol=5)

# %%
tables[3].df
# Out:
#        0    1              2                   3  4                 5     6   \
# 0
# 1  Source   ID          Type,                  RA                  Dec     r
# 2                  [redshift]         (h m s err)        (◦ ′\n′′ err)   (′)
# 3     (1)  (2)            (3)                 (4)                  (5)   (6)
# 4      46                      21:40:21.436 0.018  -  23:06:50.14 0.15  3.95
# 5      47                      21:40:21.558 0.012  -  23:14:49.49 0.15  4.04
# 6      48                      21:40:20.501 0.013  -  23:15:05.59 0.25  4.32
# 7      49                      21:40:03.419 0.020  -  23:11:34.42 0.15  4.37
# 8      50       Ellipt., 0.27  21:40:37.036 0.012  -  23:13:37.17 0.31  4.44
#
#                     7                   8                      9   \
# 0  TABLE 1 — Continued
# 1                  Cts                  C1                     C2
# 2          (0.3–7 keV)
# 3                  (7)                 (8)                    (9)
# ...

# %%
coordinates1 = [(i[0],i[3].split(' ')[0],i[5].split(' ')[0]) for i in tables[0].data[6:18]]

coordinates2 = [(i[0],i[3].split(' ')[0],i[5].split(' ')[0]) for i in tables[0].data[20:]]

coordinates3 = [(i[0],i[3].split(' ')[0],i[5].split(' ')[0]) for i in tables[2].data[3:]]
coordinates4 = [(i[0],i[3].split(' ')[0],i[5].split(' ')[0]) for i in tables[3].data[4:]]
coordinates = coordinates1 + coordinates2 + coordinates3 + coordinates4

# %%
#region to plot
findreg = 'M30.reg'


with open(findreg,'w') as fileone:
    for name,ra,dec in coordinates:
        text='fk5; circle({0},-{1},0.1") # color=red text={2} \n'.format(ra,dec,'{'+str(name)+"}")
        #text='fk5; circle({0},{1},.1") # color=red text=\{{2}\}\n'.format(ra[index],dec[index],index)
        fileone.write(text)
        #print(text)
